# %% [markdown]
# # task number 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
import seaborn as sns
sns.set(rc={'figure.figsize': [15, 5]}, font_scale=1.3)

# %%
the_data = pd.read_csv('bikes.csv')
the_data
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
the_data.describe()
# Out:
#             holiday   workingday         temp     humidity    windspeed  \
# count  10030.000000  9388.000000  8104.000000  7462.000000  6820.000000
# mean       0.029113     0.678206    20.317665    61.790673    12.708806
# std        0.168131     0.467189     7.818568    19.262084     8.131154
# min        0.000000     0.000000     0.820000     0.000000     0.000000
# 25%        0.000000     0.000000    13.940000    47.000000     7.001500
# 50%        0.000000     1.000000    20.500000    62.000000    12.998000
# 75%        0.000000     1.000000    26.240000    77.000000    16.997900
# max        1.000000     1.000000    41.000000   100.000000    56.996900
#
#              casual    registered  rented_bikes_count
# count  10886.000000  10886.000000        10886.000000
# mean      36.021955    155.552177          191.574132
# std       49.960477    151.039033          181.144454
# min        0.000000      0.000000            1.000000
# ...

# %%
the_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %% [markdown]
# # 1. Make Profit Feature.

# %%
def profit_feat(the_data):
    prof = the_data['casual']*20 + the_data['registered']*5 
    prof -= prof*0.14/100
    return  prof

# %%
the_data['profit']= the_data.apply(profit_feat , axis=1)
the_data.head()
# Out:
#               datetime  season  holiday  workingday weather  temp  humidity  \
# 0  2011-01-01 00:00:00  Spring      0.0         0.0   Clear  9.84      81.0
# 1  2011-01-01 01:00:00  Spring      0.0         0.0     NaN  9.02      80.0
# 2  2011-01-01 02:00:00  Spring      0.0         0.0   Clear  9.02       NaN
# 3  2011-01-01 03:00:00  Spring      0.0         0.0   Clear  9.84      75.0
# 4  2011-01-01 04:00:00     NaN      0.0         0.0   Clear   NaN      75.0
#
#    windspeed  casual  registered  rented_bikes_count   profit
# 0        NaN       3          13                  16  124.825
# 1        0.0       8          32                  40  319.552
# 2        0.0       5          27                  32  234.671
# 3        0.0       3          10                  13  109.846
# 4        NaN       0           1                   1    4.993

# %% [markdown]
# # 2. Distribution rental_bikes_count & profit.

# %%
histo = the_data[['rented_bikes_count','profit']].hist(bins=10)

# %% [markdown]
# # 3. Profit for each day.

# %%
the_data['date'] = pd.to_datetime(the_data['datetime'].str.split(" ",expand=True)[0])

the_data[['hours','min','sec']] = the_data['datetime'].str.split(" ",expand=True)[1].str.split(":",expand=True)
the_data['hours'] = pd.to_numeric(the_data['hours'],downcast="integer")
the_data.drop('datetime',axis=1,inplace=True)

the_data
# Out:
#        season  holiday  workingday weather   temp  humidity  windspeed  \
# 0      Spring      0.0         0.0   Clear   9.84      81.0        NaN
# 1      Spring      0.0         0.0     NaN   9.02      80.0     0.0000
# 2      Spring      0.0         0.0   Clear   9.02       NaN     0.0000
# 3      Spring      0.0         0.0   Clear   9.84      75.0     0.0000
# 4         NaN      0.0         0.0   Clear    NaN      75.0        NaN
# ...       ...      ...         ...     ...    ...       ...        ...
# 10881  Winter      0.0         1.0   Clear  15.58      50.0    26.0027
# 10882  Winter      0.0         1.0     NaN  14.76       NaN        NaN
# 10883     NaN      0.0         1.0   Clear  13.94      61.0    15.0013
# 10884  Winter      NaN         1.0   Clear  13.94       NaN     6.0032
# 10885  Winter      0.0         1.0   Clear  13.12      66.0     8.9981
#
#        casual  registered  rented_bikes_count    profit       date  hours min  \
# ...

# %%
the_data.groupby('date').sum()['profit'][:30].plot(kind='bar')

# %% [markdown]
# # 4. Which season that has more registration & profit.

# %%
the_data.groupby('season',as_index=False).sum()['season'][0]
# Out:
# 'Fall'

# %%
sns.boxplot(data = the_data, x = 'season', y = 'profit')

# %% [markdown]
# # 5. Which weather condition that has more registration & profit.

# %%
the_data.groupby('weather',as_index=False).sum()['weather'][0]
# Out:
# 'Clear'

# %%
sns.boxplot(data = the_data, x = 'weather', y = 'profit')

# %% [markdown]
# # 6. Correlation between profit & bikes count with all features.

# %%
the_data['sum_of_profit_and_bikes_count'] = (the_data['rented_bikes_count'] + the_data['profit'])
the_data.corr()['sum_of_profit_and_bikes_count']
# Out:
# holiday                          0.015028
# workingday                      -0.133912
# temp                             0.457973
# humidity                        -0.356020
# windspeed                        0.100575
# casual                           0.885652
# registered                       0.843264
# rented_bikes_count               0.947384
# profit                           0.999273
# hours                            0.390791
# sum_of_profit_and_bikes_count    1.000000
# Name: sum_of_profit_and_bikes_count, dtype: float64

# %%
sns.heatmap(the_data.corr(), annot=True, cmap = 'Blues')

# %% [markdown]
# # 7. Rentals during rush hours (7-9 am & 3-5 pm).

# %%
d=the_data[the_data['hours'].between(7, 9) | the_data['hours'].between(15, 17)][['hours','rented_bikes_count']]

# %%
sns.boxplot(y='rented_bikes_count', x='hours', data=d)

# %% [markdown]
# # 7. Rentals during workday & holiday.

# %%
the_data[(the_data['workingday']==1) | (the_data['holiday']==1)][['holiday','workingday','rented_bikes_count']]
# Out:
#        holiday  workingday  rented_bikes_count
# 47         0.0         1.0                   5
# 48         0.0         1.0                   2
# 50         0.0         1.0                   3
# 51         0.0         1.0                  30
# 52         0.0         1.0                  64
# ...        ...         ...                 ...
# 10881      0.0         1.0                 336
# 10882      0.0         1.0                 241
# 10883      0.0         1.0                 168
# 10884      NaN         1.0                 129
# 10885      0.0         1.0                  88
#
# [6659 rows x 3 columns]

# %%
sns.boxplot(y='rented_bikes_count', x='workingday',hue = 'holiday', data=the_data)

# %% [markdown]
# # 8. Registered or casual is more.

# %%
if the_data['registered'].sum() > the_data['casual'].sum():
    print ('registered is more ')
else:
    print('casual is more')
# Out:
# registered is more

# %% [markdown]
# # 9. What is the average of bikes would be registered during the week.

# %%
the_data.groupby(pd.Grouper(key='date',  freq='7D')).mean()['registered'].head(30).plot(kind = 'bar')

# %% [markdown]
# # 10. Schools (9-12) & (2-6) profit.

# %%
the_data[the_data['hours'].between(9, 12) | the_data['hours'].between(2, 6)][['hours','profit']].groupby('hours').mean().plot(kind = 'bar')

# %% [markdown]
# # 11. Profit in 2011 & Saturdays & season fall

# %%
d = the_data[(the_data['date'].dt.day_name() == 'Saturday')  & (the_data['date'].dt.year == 2011) & (the_data['season'] == 'Fall')]
d[['date','season','profit']]
# Out:
#            date season    profit
# 2714 2011-07-02   Fall  1038.544
# 2715 2011-07-02   Fall   689.034
# 2716 2011-07-02   Fall   394.447
# 2717 2011-07-02   Fall   204.713
# 2718 2011-07-02   Fall    99.860
# ...         ...    ...       ...
# 4002 2011-09-17   Fall  2326.738
# 4003 2011-09-17   Fall  1522.865
# 4004 2011-09-17   Fall  1582.781
# 4005 2011-09-17   Fall  1178.348
# 4006 2011-09-17   Fall  1218.292
#
# [187 rows x 3 columns]

# %%
d.groupby('date').sum()['profit'].plot(kind = 'bar')

# %% [markdown]
# # TASK NUMBER 2

# %% [markdown]
# ## Apply data analysis on 'loan_data.csv' dataset.
# this time you should think about the right questions to ask and apply the analysis then

# %%
data = pd.read_csv('loan_data.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # take the loan

# %%
# Graduate
data.groupby('Education').count()['LoanAmount'].plot(kind = 'pie')

# %%
#Not Married 
data.groupby('Married').count()['LoanAmount'].plot(kind = 'bar')

# %%
# Male
data.groupby('Gender').count()['LoanAmount'].plot(kind = 'bar')

# %%
# Not Self Employed 
data.groupby('Self_Employed').count()['LoanAmount'].plot(kind = 'pie')

# %%
data.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
sns.heatmap(data.corr(), annot=True, cmap = 'Blues')
